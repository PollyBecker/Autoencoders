# %% [markdown]
# <a href="https://colab.research.google.com/github/PollyBecker/Autoencoders/blob/main/Compress%C3%A3o_de_imagens_com_Autoencoders.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Compressão de imagens

# %% [markdown]
# # Etapa 1: Importação das biblitoecas

# %%
# %tensorflow_version 2.x
import tensorflow as tf
import matplotlib.pyplot as plt
import numpy as np
import os
import PIL
from tensorflow.keras import layers
import pandas as pd
import seaborn as sns
import pickle
import zipfile
import random
tf.__version__
# Out:
# Colab only includes TensorFlow 2.x; %tensorflow_version has no effect.
# '2.13.0'

# %% [markdown]
# # Etapa 2: Carregamento da base de dados

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
path = "/content/drive/My Drive/traffic-signs-data.zip"
zip_object = zipfile.ZipFile(file=path, mode="r")
zip_object.extractall("./")
zip_object.close()

# %%
with open("traffic-signs-data/train.p", mode='rb') as training_data:
    train = pickle.load(training_data)
with open("traffic-signs-data/valid.p", mode='rb') as validation_data:
    valid = pickle.load(validation_data)
with open("traffic-signs-data/test.p", mode='rb') as testing_data:
    test = pickle.load(testing_data)

# %%
X_train, y_train = train['features'], train['labels']
X_validation, y_validation = valid['features'], valid['labels']
X_test, y_test = test['features'], test['labels']

# %%
plt.imshow(X_train[1105])

# %% [markdown]
# # Etapa 3: Visualização dos dados

# %%
X_train.shape
# Out:
# (34799, 32, 32, 3)

# %%
X_test.shape
# Out:
# (12630, 32, 32, 3)

# %%
i = random.randint(1,34000)
plt.imshow( X_train[i] , cmap = 'gray')

# %%
label = y_train[i]
label
# Out:
# 2

# %%
W_grid = 10
L_grid = 10

fig, axes = plt.subplots(L_grid, W_grid, figsize = (17,17))

axes = axes.ravel()
n_training = len(X_train)

for i in np.arange(0, W_grid * L_grid):
    index = np.random.randint(0, n_training)
    axes[i].imshow( X_train[index] )
    axes[i].set_title(y_train[index], fontsize = 8)
    axes[i].axis('off')
plt.subplots_adjust(hspace=0.4)

# %% [markdown]
# # Etapa 4: Pré-processamento

# %%
X_train = X_train / 255
X_test = X_test / 255

# %% [markdown]
# # Etapa 5: Criação e treinamento do autoencoder

# %%
autoencoder = tf.keras.models.Sequential()

# Encoder
autoencoder.add(tf.keras.layers.Conv2D(64, (3,3), strides=1, padding="same", input_shape=(32, 32, 3)))
autoencoder.add(tf.keras.layers.BatchNormalization())
autoencoder.add(tf.keras.layers.Activation('relu'))
autoencoder.add(tf.keras.layers.AveragePooling2D((2,2), padding="same"))

autoencoder.add(tf.keras.layers.Conv2D(32, (3,3), strides=1, padding="same"))
autoencoder.add(tf.keras.layers.BatchNormalization())
autoencoder.add(tf.keras.layers.Activation('relu'))
autoencoder.add(tf.keras.layers.AveragePooling2D((2,2), padding="same"))

autoencoder.add(tf.keras.layers.Conv2D(16, (3,3), strides=1, padding="same"))
autoencoder.add(tf.keras.layers.BatchNormalization())
autoencoder.add(tf.keras.layers.Activation('relu'))

# Encoded image (Code Layer)
autoencoder.add(tf.keras.layers.AveragePooling2D((2,2), padding="same"))

# Decoder
autoencoder.add(tf.keras.layers.Conv2D(16, (3,3), strides=1, padding="same"))
autoencoder.add(tf.keras.layers.BatchNormalization())
autoencoder.add(tf.keras.layers.Activation('relu'))
autoencoder.add(tf.keras.layers.UpSampling2D((2, 2)))

autoencoder.add(tf.keras.layers.Conv2D(32, (3,3), strides=1, padding="same"))
autoencoder.add(tf.keras.layers.BatchNormalization())
autoencoder.add(tf.keras.layers.Activation('relu'))
autoencoder.add(tf.keras.layers.UpSampling2D((2, 2)))

autoencoder.add(tf.keras.layers.Conv2D(64, (3,3), strides=1, padding="same"))
autoencoder.add(tf.keras.layers.BatchNormalization())
autoencoder.add(tf.keras.layers.Activation('relu'))
autoencoder.add(tf.keras.layers.UpSampling2D((2, 2)))

# Aqui tem tres filtros ja que ele deve retornar 3 canais (R,G,B)
autoencoder.add(tf.keras.layers.Conv2D(3, (3,3), strides=1, activation='sigmoid', padding="same"))

# %%
autoencoder.compile(loss='binary_crossentropy', optimizer=tf.keras.optimizers.Adam(lr=0.01))
autoencoder.summary()
# Out:
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 32, 32, 64)        1792
#
#  batch_normalization (Batch  (None, 32, 32, 64)        256
#  Normalization)
#
#  activation (Activation)     (None, 32, 32, 64)        0
#
#  average_pooling2d (Average  (None, 16, 16, 64)        0
#  Pooling2D)
#
#  conv2d_1 (Conv2D)           (None, 16, 16, 32)        18464
#
#  batch_normalization_1 (Bat  (None, 16, 16, 32)        128
#  chNormalization)
#
#  activation_1 (Activation)   (None, 16, 16, 32)        0
#
#  average_pooling2d_1 (Avera  (None, 8, 8, 32)          0
#  gePooling2D)
#
#  conv2d_2 (Conv2D)           (None, 8, 8, 16)          4624
#
#  batch_normalization_2 (Bat  (None, 8, 8, 16)          64
#  chNormalization)
#
#  activation_2 (Activation)   (None, 8, 8, 16)          0
#
#  average_pooling2d_2 (Avera  (None, 4, 4, 16)          0
#  gePooling2D)
#
#  conv2d_3 (Conv2D)           (None, 4, 4, 16)          2320
#
#  batch_normalization_3 (Bat  (None, 4, 4, 16)          64
#  chNormalization)
#
#  activation_3 (Activation)   (None, 4, 4, 16)          0
#
#  up_sampling2d (UpSampling2  (None, 8, 8, 16)          0
#  D)
#
#  conv2d_4 (Conv2D)           (None, 8, 8, 32)          4640
#
#  batch_normalization_4 (Bat  (None, 8, 8, 32)          128
#  chNormalization)
#
#  activation_4 (Activation)   (None, 8, 8, 32)          0
#
#  up_sampling2d_1 (UpSamplin  (None, 16, 16, 32)        0
#  g2D)
#
#  conv2d_5 (Conv2D)           (None, 16, 16, 64)        18496
#
#  batch_normalization_5 (Bat  (None, 16, 16, 64)        256
#  chNormalization)
#
#  activation_5 (Activation)   (None, 16, 16, 64)        0
#
#  up_sampling2d_2 (UpSamplin  (None, 32, 32, 64)        0
#  g2D)
#
#  conv2d_6 (Conv2D)           (None, 32, 32, 3)         1731
#
# =================================================================
# Total params: 52963 (206.89 KB)
# Trainable params: 52515 (205.14 KB)
# Non-trainable params: 448 (1.75 KB)
# _________________________________________________________________

# %%
#Aqui eu passo X_train e X_train novamente já que meu traget é a propria imagem
autoencoder.fit(X_train,
          X_train,
          epochs=20,
          batch_size=200,
          validation_data=(X_test, X_test))
# Out:
# Epoch 1/20
# 174/174 [==============================] - 22s 41ms/step - loss: 0.5050 - val_loss: 0.5911
# Epoch 2/20
# 174/174 [==============================] - 4s 26ms/step - loss: 0.4872 - val_loss: 0.5224
# Epoch 3/20
# 174/174 [==============================] - 4s 25ms/step - loss: 0.4839 - val_loss: 0.4900
# Epoch 4/20
# 174/174 [==============================] - 5s 28ms/step - loss: 0.4814 - val_loss: 0.4795
# Epoch 5/20
# 174/174 [==============================] - 4s 25ms/step - loss: 0.4798 - val_loss: 0.4776
# Epoch 6/20
# 174/174 [==============================] - 4s 26ms/step - loss: 0.4788 - val_loss: 0.4797
# Epoch 7/20
# 174/174 [==============================] - 6s 32ms/step - loss: 0.4778 - val_loss: 0.4750
# Epoch 8/20
# 174/174 [==============================] - 6s 33ms/step - loss: 0.4770 - val_loss: 0.4759
# Epoch 9/20
# 174/174 [==============================] - 6s 34ms/step - loss: 0.4764 - val_loss: 0.4740
# Epoch 10/20
# 174/174 [==============================] - 6s 34ms/step - loss: 0.4754 - val_loss: 0.4738
# Epoch 11/20
# 174/174 [==============================] - 5s 28ms/step - loss: 0.4750 - val_loss: 0.4732
# Epoch 12/20
# 174/174 [==============================] - 6s 36ms/step - loss: 0.4747 - val_loss: 0.4838
# Epoch 13/20
# 174/174 [==============================] - 5s 26ms/step - loss: 0.4738 - val_loss: 0.4713
# Epoch 14/20
# 174/174 [==============================] - 4s 26ms/step - loss: 0.4735 - val_loss: 0.4730
# Epoch 15/20
# 174/174 [==============================] - 5s 27ms/step - loss: 0.4729 - val_loss: 0.4705
# Epoch 16/20
# 174/174 [==============================] - 4s 26ms/step - loss: 0.4727 - val_loss: 0.4724
# Epoch 17/20
# 174/174 [==============================] - 4s 26ms/step - loss: 0.4724 - val_loss: 0.4701
# Epoch 18/20
# 174/174 [==============================] - 5s 28ms/step - loss: 0.4723 - val_loss: 0.4728
# Epoch 19/20
# 174/174 [==============================] - 5s 26ms/step - loss: 0.4717 - val_loss: 0.4703
# Epoch 20/20
# 174/174 [==============================] - 5s 31ms/step - loss: 0.4714 - val_loss: 0.4751

# %% [markdown]
# # Etapa 6: Avaliação do modelo

# %%
predicted = autoencoder.predict(X_test[:10].reshape(-1, 32, 32, 3))
# Out:
# 1/1 [==============================] - 0s 417ms/step

# %%
predicted.shape
# Out:
# (10, 32, 32, 3)

# %%
fig, axes = plt.subplots(nrows=2, ncols=10, sharex=True, sharey=True, figsize=(20,4))
for images, row in zip([X_test[:10], predicted], axes):
    for img, ax in zip(images, row):
        ax.imshow(img.reshape((32, 32, 3)))
        ax.get_xaxis().set_visible(False)
        ax.get_yaxis().set_visible(False)
